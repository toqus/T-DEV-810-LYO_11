# %% [markdown]
# <a href="https://colab.research.google.com/github/toqus/T-DEV-810-LYO_11/blob/main/T_DEV_810.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center> Project T-DEV-810 </center></h1>
#
# <center> Taoufik JARMOUNI and Mykyta Yevtushevskyi &nbsp;&nbsp;&nbsp; | &nbsp;&nbsp;&nbsp; Epitech &nbsp;&nbsp;&nbsp; </center>

# %% [markdown]
# ---

# %% [markdown]
# **IMPORT ALL THE IMAGES (TRAIN/NORMAL) FROM GITHUB**

# %%
import requests
from PIL import Image
from io import BytesIO
from bs4 import BeautifulSoup

url = "https://github.com/toqus/T-DEV-810-LYO_11/tree/main/datasets/chest_Xray/train/NORMAL"

page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

images = []
image_urls = []
for link in soup.find_all('a'):
    href = link.get('href')
    if href.endswith('.jpeg'):
        image_urls.append('https://raw.githubusercontent.com' + href.replace('/blob', ''))

for image_url in image_urls:
    response = requests.get(image_url)
    if response.status_code == 200:
        img = Image.open(BytesIO(response.content))
        images.append(img)

# %%
print(images)
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=L size=2090x1858 at 0x7F787FF7BFD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1422x1152 at 0x7F78944F3B80>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1810x1434 at 0x7F7887721CA0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1618x1279 at 0x7F78860107C0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1600x1125 at 0x7F78944F3520>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1974x1306 at 0x7F78944F3CA0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1528x1013 at 0x7F7886BF4940>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1384x1167 at 0x7F7886BF4CD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1450x1144 at 0x7F7887721910>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1468x993 at 0x7F7887721B80>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1724x1581 at 0x7F78844B4520>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1346x1044 at 0x7F78844B4820>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1156x1237 at 0x7F78844B4430>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1740x1453 at 0x7F787FF7BEB0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2138x1928 at 0x7F7887721AC0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1596x1156 at 0x7F78844B43A0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2102x1974 at 0x7F7885D60100>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1542x1152 at 0x7F78944E9AF0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1518x1156 at 0x7F7887721CD0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1612x1133 at 0x7F78844B4130>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1844x1438 at 0x7F78844B4910>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1488x1209 at 0x7F7885D60460>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=994x758 at 0x7F78844B4B50>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1750x1314 at 0x7F78844B4460>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1762x1430 at 0x7F78844B4340>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1202x808 at 0x7F7885D60EE0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1972x1719 at 0x7F7885D60970>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1534x1187 at 0x7F7885D578B0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2148x1496 at 0x7F7885D57280>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1876x1893 at 0x7F78844B49D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1680x1557 at 0x7F7886BF4760>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2172x1615 at 0x7F7885D60250>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1646x1124 at 0x7F7885D57940>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2136x1650 at 0x7F78844B40D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1372x1005 at 0x7F78844B4BE0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2338x2025 at 0x7F7885D607C0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1458x1190 at 0x7F7885D605B0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1854x1572 at 0x7F78844B4AC0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1466x1109 at 0x7F7885D57790>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2164x1746 at 0x7F7885D586D0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=2010x1747 at 0x7F7885D57370>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1774x1546 at 0x7F7885D57E80>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1506x833 at 0x7F78844B4DF0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1446x1310 at 0x7F7887721EB0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1434x1260 at 0x7F7885D58100>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1554x1075 at 0x7F7886010AC0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1040x747 at 0x7F78844B4610>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1426x1049 at 0x7F7885D58160>, <PIL.JpegImagePlugin. ...
