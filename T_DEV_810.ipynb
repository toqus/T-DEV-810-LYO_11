# %% [markdown]
# <a href="https://colab.research.google.com/github/toqus/T-DEV-810-LYO_11/blob/main/T_DEV_810.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center> Project T-DEV-810 </center></h1>
#
# <center> Taoufik JARMOUNI and Mykyta Yevtushevskyi &nbsp;&nbsp;&nbsp; | &nbsp;&nbsp;&nbsp; Epitech &nbsp;&nbsp;&nbsp; </center>

# %% [markdown]
# ---

# %%
pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **IMPORT ALL THE IMAGES (TRAIN/NORMAL AND PNEUMONIA) FROM GITHUB**

# %%
import requests
from PIL import Image
from io import BytesIO
from bs4 import BeautifulSoup


def get_images_from_github_directory(method, type_name):
  url = "https://github.com/toqus/T-DEV-810-LYO_11/tree/main/datasets/chest_Xray/" + method + type_name

  page = requests.get(url)
  soup = BeautifulSoup(page.content, 'html.parser')

  images = []
  image_urls = []
  for link in soup.find_all('a'):
      href = link.get('href')
      if href.endswith('.jpeg'):
          image_urls.append('https://raw.githubusercontent.com' + href.replace('/blob', ''))

  for image_url in image_urls:
      response = requests.get(image_url)
      if response.status_code == 200:
          img = Image.open(BytesIO(response.content))
          images.append(img)

  return images

images_normal_train = get_images_from_github_directory("train/", "NORMAL")
images_pneumonia_train = get_images_from_github_directory("train/", "PNEUMONIA")

images_normal_test = get_images_from_github_directory("test/", "NORMAL")
images_pneumonia_test = get_images_from_github_directory("test/", "PNEUMONIA")

images_normal_val = get_images_from_github_directory("val/", "NORMAL")
images_pneumonia_val = get_images_from_github_directory("val/", "PNEUMONIA")

# %%
print(images_normal_train)
print(images_pneumonia_train)

print(images_normal_test)
print(images_pneumonia_test)

print(images_normal_val)
print(images_pneumonia_val)
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=L size=2090x1858 at 0x7F49BEC0DEE0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1422x1152 at 0x7F49BFFCD100>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1810x1434 at 0x7F49BFFCD130>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1618x1279 at 0x7F49E407BD30>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1600x1125 at 0x7F49BEC0DD30>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1974x1306 at 0x7F49BFFCD850>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1528x1013 at 0x7F4A020B2940>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1384x1167 at 0x7F49BFFA9520>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1450x1144 at 0x7F49BFFCD820>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1468x993 at 0x7F49BFF99FA0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1724x1581 at 0x7F49BFFCD4F0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1346x1044 at 0x7F49BFFA9A00>, <P
# ...

# %% [markdown]
# ---

# %% [markdown]
# **CONVERT LISTS OF IMAGES TO NUMPY ARRAYS**

# %%
import numpy as np

images_normal_train_numpy = np.array([np.array(img) for img in images_normal_train])
images_pneumonia_train_numpy = np.array([np.array(img) for img in images_pneumonia_train])

images_normal_test_numpy = np.array([np.array(img) for img in images_normal_test])
images_pneumonia_test_numpy = np.array([np.array(img) for img in images_pneumonia_test])

images_normal_val_numpy = np.array([np.array(img) for img in images_normal_val])
images_pneumonia_val_numpy = np.array([np.array(img) for img in images_pneumonia_val])
# Out:
# <ipython-input-5-9b34788167af>:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   images_normal_train_numpy = np.array([np.array(img) for img in images_normal_train])
# <ipython-input-5-9b34788167af>:4: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   images_pneumonia_train_numpy = np.array([np.array(img) for img in images_pneumonia_train])
# ...
