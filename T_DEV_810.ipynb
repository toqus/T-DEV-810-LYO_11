# %% [markdown]
# <a href="https://colab.research.google.com/github/toqus/T-DEV-810-LYO_11/blob/main/T_DEV_810.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1><center> Project T-DEV-810 </center></h1>
#
# <center> Taoufik JARMOUNI and Mykyta Yevtushevskyi &nbsp;&nbsp;&nbsp; | &nbsp;&nbsp;&nbsp; Epitech &nbsp;&nbsp;&nbsp; </center>

# %% [markdown]
# ---

# %%
pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **IMPORT ALL THE IMAGES (TRAIN/NORMAL) FROM GITHUB**

# %%
import requests
from PIL import Image
from io import BytesIO
from bs4 import BeautifulSoup


def get_images_from_github_directory(type_name):
  url = "https://github.com/toqus/T-DEV-810-LYO_11/tree/main/datasets/chest_Xray/train/" + type_name

  page = requests.get(url)
  soup = BeautifulSoup(page.content, 'html.parser')

  images = []
  image_urls = []
  for link in soup.find_all('a'):
      href = link.get('href')
      if href.endswith('.jpeg'):
          image_urls.append('https://raw.githubusercontent.com' + href.replace('/blob', ''))

  for image_url in image_urls:
      response = requests.get(image_url)
      if response.status_code == 200:
          img = Image.open(BytesIO(response.content))
          images.append(img)

  return images

images_normal = get_images_from_github_directory("NORMAL")
images_pneumonia = get_images_from_github_directory("PNEUMONIA")

# %%
print(images_normal)
print(images_pneumonia)
# Out:
# [<PIL.JpegImagePlugin.JpegImageFile image mode=L size=2090x1858 at 0x7F781C6D9DC0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1422x1152 at 0x7F781C6D9C70>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1810x1434 at 0x7F781C6D9DF0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1618x1279 at 0x7F781C6D9BB0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1600x1125 at 0x7F781C68F280>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1974x1306 at 0x7F781EF417C0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1528x1013 at 0x7F781C6D9CA0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1384x1167 at 0x7F781EF41100>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1450x1144 at 0x7F781C68F400>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1468x993 at 0x7F781C68F970>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1724x1581 at 0x7F781C68FAF0>, <PIL.JpegImagePlugin.JpegImageFile image mode=L size=1346x1044 at 0x7F781EF413D0>, <P
# ...
